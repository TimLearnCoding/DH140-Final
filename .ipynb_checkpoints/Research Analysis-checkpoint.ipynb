# %% [markdown]
# # Research Analysis

# %%
import pandas as pd

file_path = 'classics.csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Check if the file is loaded sucessfully
df.head()
# Out:
#   bibliography.congress classifications bibliography.languages  \
# 0                                    PR                     en
# 1                                    PS                     en
# 2                                 PZ,PR                     en
# 3                                    PR                     en
# 4                                    PT                     en
#
#                                bibliography.subjects  \
# 0  Sisters -- Fiction,Courtship -- Fiction,Social...
# 1  Mentally ill women -- Fiction,Feminist fiction...
# 2                                            Fantasy
# 3  Monsters -- Fiction;Frankenstein's monster (Fi...
# 4     Psychological fiction,Metamorphosis -- Fiction
#
#                         bibliography.title bibliography.type  \
# 0                      Pride and Prejudice              Text
# 1                     The Yellow Wallpaper              Text
# 2         Alice's Adventures in Wonderland              Text
# ...

# %% [markdown]
# ## 1. Compare Lewis Carroll to the other popular authors and discover insights about his writing style.

# %%
df[df['bibliography.author.name'] == "Carroll, Lewis"]
# Out:
#     bibliography.congress classifications bibliography.languages  \
# 2                                   PZ,PR                     en
# 67                                  PR,PZ                     en
# 183                                 PZ,PR                     en
# 275                                 PZ,PR                     en
# 654                                 PR,PZ                     de
# 733                                    BC                     en
# 790                                    BC                     en
#
#                                  bibliography.subjects  \
# 2                                              Fantasy
# 67                                             Fantasy
# 183                                            Fantasy
# 275                                            Fantasy
# 654                                            Fantasy
# 733  Logic -- Juvenile literature;Logic, Symbolic a...
# 790                   Logic, Symbolic and mathematical
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt


dt_sentence_length = df['metrics.statistics.average sentence length']

plt.hist(dt_sentence_length[dt_sentence_length <100], bins = len(dt_sentence_length) ,edgecolor='black')

# Add labels and title
plt.xlabel('Average sentence length')
plt.ylabel('Frequency')
plt.title('Visualization1: average sentence length')

# Display the histogram
plt.show()

# %% [markdown]
# Visualization 2: Mark Lewis's average sentence length on this graph for comparison.

# %% [markdown]
# ## 2. What the mood change in *Alice's Adventures in Wonderland* along with its storyline?

# %% [markdown]
# I copy some useful codes from assignment 5 and will modify them later.

# %%
import requests
import matplotlib.pyplot as plt
import nltk

from nltk.tokenize import word_tokenize
from nltk.sentiment import vader
from nltk.corpus import stopwords
from nltk.corpus import opinion_lexicon
from nltk.stem.porter import PorterStemmer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')
nltk.download('opinion_lexicon')
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!
# True

# %%
target_url = "https://www.gutenberg.org/files/11/11-0.txt"
response = requests.get(target_url)
alice_string = response.text
alice_string = alice_string.split('*** START OF THE PROJECT GUTENBERG EBOOK Alice ***')[1]
alice_string = alice_string.split('*** END OF THE PROJECT GUTENBERG EBOOK Alice ***')[0]
alice_string = alice_string.lower()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 4
#       2 response = requests.get(target_url)
#       3 alice_string = response.text
# ----> 4 alice_string = alice_string.split('*** START OF THE PROJECT GUTENBERG EBOOK Alice ***')[1]
#       5 alice_string = alice_string.split('*** END OF THE PROJECT GUTENBERG EBOOK Alice ***')[0]
#       6 alice_string = alice_string.lower()
#
# IndexError: list index out of range

# %%
# a Python list of stopwords
stop_words = stopwords.words('english')
# a variable for using VADER's SentimentIntensityAnalyzer
analyzer = vader.SentimentIntensityAnalyzer()

# %%
# Initialize lists to store scene numbers and sentiment scores
scene_numbers = []
sentiment_scores = []

# Iterate over the scenes in Romeo and Juliet
for i, scene_text in enumerate(r_j_scenes, 1):
    # Tokenize the scene's text into words
    words = nltk.word_tokenize(scene_text)
    
    # Calculate the total scene sentiment score by summing the compound scores of all the words in that scene
    scene_score = sum(analyzer.polarity_scores(word)["compound"] for word in words)
    
    # Append scene number and sentiment score to the respective lists
    scene_numbers.append(i)
    sentiment_scores.append(scene_score)

# %%
# Make a bar plot with scene numbers on the horizontal axis and sentiment scores as the bar heights
plt.figure(figsize=(12, 6))

# Set colors for positive, negative, and neutral scores
colors = ['purple' if score < 0 else 'orange' if score > 0 else 'blue' for score in sentiment_scores]
bar_width = 0.5

plt.bar(scene_numbers, sentiment_scores,color=colors,width = bar_width)
plt.xlabel("Scene Number")
plt.ylabel("Sentiment Score")
plt.title("Alice's Adventure in Wonderland")
plt.xticks(scene_numbers)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 plt.figure(figsize=(12, 6))
#       4 # Set colors for positive, negative, and neutral scores
# ----> 5 colors = ['purple' if score < 0 else 'orange' if score > 0 else 'blue' for score in sentiment_scores]
#       6 bar_width = 0.5
#       8 plt.bar(scene_numbers, sentiment_scores,color=colors,width = bar_width)
#
# NameError: name 'sentiment_scores' is not defined

# %% [markdown]
# Visualization3: make a sentiment polarity grahph like we did in assignment 5 for each chapter of the book, where we can see the mood change through the use of total positive/negative words.

# %% [markdown]
# ## 3. Who are the main characters in *Alice's Adventures in Wonderland* and which characters are relevant to them?

# %% [markdown]
# Visualization 4: Make a network graph to demonstrate the main characters' relation with other roles.
